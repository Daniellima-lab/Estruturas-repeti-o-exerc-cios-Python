# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniellima913/Estruturas-repeti-o-exerc-cios-Python/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install mongo
from pymongo import MongoClient
# Out:
# Collecting mongo
#   Downloading mongo-0.2.0.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymongo (from mongo)
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo->mongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.7 MB/s eta 0:00:00
# Building wheels for collected packages: mongo
#   Building wheel for mongo (setup.py) ... done
#   Created wheel for mongo: filename=mongo-0.2.0-py3-none-any.whl size=4935 sha256=a9aba01aa4efe495ffb003e4b483c9d6742464ee6dd4cd71c13e3560d88c16d0
#   Stored in directory: /root/.cache/pip/wheels/3e/74/1e/a910658709522cedacd7097eeb20d691cf8066f94fc33efacf
# Successfully built mongo
# Installing collected packages: dnspython, pymongo, mongo
# Successfully installed dnspython-2.7.0 mongo-0.2.0 pymongo-4.10.1

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
#Convertendo um arquivo csv em um Data Freme Pandas

estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
# Convertendo em um dicionario
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient("mongodb+srv://daniellima913:12345@clusterestadios.bdo25.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('671ae3c30f65dc0f9d405ca8'), ObjectId('671ae3c30f65dc0f9d405ca9'), ObjectId('671ae3c30f65dc0f9d405caa'), ObjectId('671ae3c30f65dc0f9d405cab'), ObjectId('671ae3c30f65dc0f9d405cac'), ObjectId('671ae3c30f65dc0f9d405cad'), ObjectId('671ae3c30f65dc0f9d405cae'), ObjectId('671ae3c30f65dc0f9d405caf'), ObjectId('671ae3c30f65dc0f9d405cb0'), ObjectId('671ae3c30f65dc0f9d405cb1'), ObjectId('671ae3c30f65dc0f9d405cb2'), ObjectId('671ae3c30f65dc0f9d405cb3'), ObjectId('671ae3c30f65dc0f9d405cb4'), ObjectId('671ae3c30f65dc0f9d405cb5'), ObjectId('671ae3c30f65dc0f9d405cb6'), ObjectId('671ae3c30f65dc0f9d405cb7'), ObjectId('671ae3c30f65dc0f9d405cb8'), ObjectId('671ae3c30f65dc0f9d405cb9'), ObjectId('671ae3c30f65dc0f9d405cba'), ObjectId('671ae3c30f65dc0f9d405cbb')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-01.bdo25.mongodb.net:27017', 'clusterestadios-shard-00-00.bdo25.mongodb.net:27017', 'clusterestadios-shard-00-02.bdo25.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-127g1g-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('671ae36630ee96fdc61d56e3'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405ca8'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405ca9'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405caa'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cab'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cac'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cad'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cae'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405caf'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb0'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb1'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb2'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb3'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb4'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb5'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb6'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb7'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb8'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cb9'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cba'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('671ae3c30f65dc0f9d405cbb'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
#Converte em um DataFrame
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           671ae36630ee96fdc61d56e3
# nome                 Arena da Amazônia
# capacidade                       44000
# latitude                      -3.08434
# longitude                     -60.0265
# Name: 0, dtype: object

# %%
#Cria um mapa a partir do ponto central com 800x600
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width='800px', height='600px')

# %%
#Recuperando a quantidade de pontos
qtde = len(df_convertido)

# %%
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  description = 'Estádio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
  folium.Marker([lat, lng],
                popup=description,
                icon =  folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45c918e00dd5662acd9ee392c4886bf1 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45c918e00dd5662acd9ee392c4886bf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45c918e00dd5662acd9ee392c4886bf1 = L.map(
#                 &quot;map_45c918e00dd5662acd9ee392c4886bf1&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc3148513bf1b9812ae0c4b9331d7417 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cc3148513bf1b9812ae0c4b9331d7417.addTo(map_45c918e00dd5662acd9ee392c4886bf1);
#
#
#             var marker_f4d7e70b33ee0c28b1e02e06bdea6635 = L.marker(
#                 [-3.08434, -60.0265],
#                 {}
#             ).addTo(map_45c918e00dd5662acd9ee392c4886bf1);
#
#
#             var icon_f4106391abe456d85941ad5ca500c7d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f4d7e70b33ee0c28b1e02e06bdea6635.setIcon(icon_f4106391abe456d85941ad5ca500c7d4);
#
#
#         var popup_dfd692821bb4a270faf6ef9cb53c149a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_421ae523a93c64503ccc79cf397f9006 = $(`&lt;div id=&quot;html_421ae523a93c64503ccc79cf397f9006&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Arena da Amazônia&lt;br&gt; Capacidade: 44000&lt;/div&gt;`)[0];
#                 popup_dfd692821bb4a270faf6ef9cb53c149a.setContent(html_421ae523a93c64503ccc79cf397f9006);
#
#
#
#         marker_f4d7e70b33ee0c28b1e02e06bdea6635.bindPopup(popup_dfd692821bb4a270faf6ef9cb53c149a)
#         ;
#
#
#
#
#             var marker_530372c08adca6d5ba7c50a660b108dc = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_45c918e00dd5662acd9ee392c4886bf1);
#
#
#             var icon_6bcf3fda9bb4f7b813e5671061e71e30 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_530372c08adca6d5ba7c50a660b108dc.setIcon(icon_6bcf3fda9bb4f7b813e5671061e71e30);
#
#
#         var popup_6a32bd623233f925e297172fae64e175 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e524fb7a50010d0bde31338a89642f14 = $(`&lt;div id=&quot;html_e524fb7a50010d0bde31338a89642f14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_6a32bd623233f925e297172fae64e175.setContent(html_e524fb7a50010d0bde31338a89642f14);
#
#
#
#         marker_530372c08adca6d5ba7c50a660b108dc.bindPopup(popup_6a32bd623233f925e297172fae64e175)
#         ;
#
#
#
#
#             var marker_2d2606ac50b61f8531add44a23877db9 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_45c918e00dd5662acd9ee392c4886bf1);
#
#
#             var icon_e03b37b4ce83cb11e5d46a67474d3889 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d2606ac50b61f8531add44a23877db9.setIcon(icon_e03b37b4ce83cb11e5d46a67474d3889);
#
#
#         var popup_0751958044713cccd2f6aa8cabfddec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4210123da3479743ca89f161abd6348 = $(`&lt;div id=&quot;html_a4210123da3479743ca89f161abd6348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_0751958044713cccd2f6aa8cabfddec6.setContent(html_a4210123da3479743ca89f161abd6348);
#
#
#
#         marker_2d2606ac50b61f8531add44a23877db9.bindPopup(popup_0751958044713cccd2f6aa8cabfddec6)
#         ;
#
#
#
#
#             var marker_1bc5feeb65aea26a044cc8ba8de1c010 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_45c918e00dd5662acd9ee392c4886bf1);
#
#
#             var icon_704b35173aebffc9cd6cb51522b7a7e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;
